# %%
from os import listdir
from numpy import asarray, save
from keras.utils import load_img, img_to_array

# %%
folder = '/content/drive/MyDrive/Colab Notebooks/Data/Flower/Train/'
photos, labels = list(), list()
for file in listdir(folder):
  if file.startswith('daisy'):
    output = 1.0
  if file.startswith('lotus'):
    output = 2.0
  if file.startswith('rose'):
    output = 3.0
  if file.startswith('sakura'):
    output = 4.0
  if file.startswith('sun'):
    output = 5.0

  photo = load_img(folder + file, target_size =(128,128))
  photo = img_to_array(photo)
  photos.append(photo)
  labels.append(output)

photos_train = asarray(photos)
labels_train = asarray(labels)
print(photos_train.shape, labels_train.shape)
# Out:
# (124, 128, 128, 3) (124,)

# %%
folder = '/content/drive/MyDrive/Colab Notebooks/Data/Flower/Test/'
photos, labels = list(), list()
for file in listdir(folder):
  if file.startswith('daisy'):
    output = 1.0
  if file.startswith('lotus'):
    output = 2.0
  if file.startswith('rose'):
    output = 3.0
  if file.startswith('sakura'):
    output = 4.0
  if file.startswith('sun'):
    output = 5.0

  photo = load_img(folder + file, target_size =(128,128))
  photo = img_to_array(photo)
  photos.append(photo)
  labels.append(output)

photos_test = asarray(photos)
labels_test = asarray(labels)
print(photos_test.shape, labels_test.shape)
# Out:
# (40, 128, 128, 3) (40,)

# %%
photos_train = photos_train.reshape(124, 128, 128, 3)
photos_train = photos_train.astype('float32')/255 
photos_test = photos_test.reshape(40, 128, 128, 3)
photos_test = photos_test.astype('float32')/255



from keras.utils import  to_categorical
labels_train = to_categorical(labels_train)
labels_test = to_categorical(labels_test)
photos_train.shape, labels_train.shape, photos_test.shape, labels_test.shape
# Out:
# ((124, 128, 128, 3), (124, 6), (40, 128, 128, 3), (40, 6))

# %%
fine_labels = [
    'sun',
    'daisy',
    'lotus',
    'rose',
    'sakura',
]

class_names = {}
counter = 0      

for instances in fine_labels:
  class_names.update({counter: instances})   
  counter+=1

# %%
from keras.models import Sequential, Model
from keras import Input, Model
from keras.optimizers import Adam
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D
from keras.layers import BatchNormalization, LeakyReLU

# %%
model = Sequential()

model.add(Conv2D(32, kernel_size = (3,3), activation = 'linear',
                 input_shape = (128,128,3), padding = 'same')) 

model.add(LeakyReLU(alpha = 0.1))
model.add(MaxPooling2D((2,2), padding = 'same'))

model.add(Conv2D(64, (3,3), activation = 'linear', padding ='same'))
model.add(LeakyReLU(alpha = 0.1))
model.add(MaxPooling2D((2,2), padding = 'same'))

model.add(Conv2D(128, (3,3), activation = 'linear', padding = 'same'))
model.add(LeakyReLU(alpha = 0.1))
model.add(MaxPooling2D((2,2), padding = 'same'))


model.add(Flatten())
model.add(Dense(128, activation = 'linear'))
model.add(LeakyReLU(alpha = 0.1))
model.add(Dense(6, activation ='softmax'))

# %%
model.compile(optimizer = Adam(), loss = 'categorical_crossentropy', 
              metrics = ['accuracy'])
model.summary()

train = model.fit(photos_train, labels_train, batch_size = 128 , 
                  epochs = 30, verbose = 1)

test_loss, test_acc = model.evaluate(photos_test, labels_test)
print('DO CHINH XAC', test_acc)
print('HAM MAT MAT', test_loss)
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_9 (Conv2D)           (None, 128, 128, 32)      896
#
#  leaky_re_lu_12 (LeakyReLU)  (None, 128, 128, 32)      0
#
#  max_pooling2d_9 (MaxPooling  (None, 64, 64, 32)       0
#  2D)
#
#  conv2d_10 (Conv2D)          (None, 64, 64, 64)        18496
#
#  leaky_re_lu_13 (LeakyReLU)  (None, 64, 64, 64)        0
#
#  max_pooling2d_10 (MaxPoolin  (None, 32, 32, 64)       0
#  g2D)
#
#  conv2d_11 (Conv2D)          (None, 32, 32, 128)       73856
#
#  leaky_re_lu_14 (LeakyReLU)  (None, 32, 32, 128)       0
#
#  max_pooling2d_11 (MaxPoolin  (None, 16, 16, 128)      0
#  g2D)
#
#  flatten_3 (Flatten)         (None, 32768)             0
#
#  dense_6 (Dense)             (None, 128)               4194432
#
#  leaky_re_lu_15 (LeakyReLU)  (None, 128)               0
#
#  dense_7 (Dense)             (None, 6)                 774
#
# =================================================================
# Total params: 4,288,454
# Trainable params: 4,288,454
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 1/1 [==============================] - 7s 7s/step - loss: 2.8304 - accuracy: 0.3548
# Epoch 2/30
# 1/1 [==============================] - 5s 5s/step - loss: 1.8313 - accuracy: 0.4516
# Epoch 3/30
# 1/1 [==============================] - 7s 7s/step - loss: 1.8248 - accuracy: 0.3629
# Epoch 4/30
# 1/1 [==============================] - 5s 5s/step - loss: 1.4274 - accuracy: 0.3468
# Epoch 5/30
# 1/1 [==============================] - 6s 6s/step - loss: 1.1423 - accuracy: 0.5887
# Epoch 6/30
# 1/1 [==============================] - 6s 6s/step - loss: 1.2404 - accuracy: 0.5484
# Epoch 7/30
# 1/1 [==============================] - 5s 5s/step - loss: 1.0740 - accuracy: 0.5484
# Epoch 8/30
# 1/1 [==============================] - 7s 7s/step - loss: 0.9220 - accuracy: 0.7097
# Epoch 9/30
# 1/1 [==============================] - 5s 5s/step - loss: 0.7585 - accuracy: 0.7258
# Epoch 10/30
# 1/1 [==============================] - 5s 5s/step - loss: 0.7505 - accuracy: 0.6452
# Epoch 11/30
# 1/1 [==============================] - 7s 7s/step - loss: 0.5934 - accuracy: 0.7903
# Epoch 12/30
# 1/1 [==============================] - 5s 5s/step - loss: 0.5316 - accuracy: 0.7903
# Epoch 13/30
# 1/1 [==============================] - 5s 5s/step - loss: 0.4848 - accuracy: 0.7984
# Epoch 14/30
# 1/1 [==============================] - 6s 6s/step - loss: 0.4831 - accuracy: 0.7984
# Epoch 15/30
# 1/1 [==============================] - 5s 5s/step - loss: 0.3616 - accuracy: 0.8468
# Epoch 16/30
# 1/1 [==============================] - 7s 7s/step - loss: 0.3165 - accuracy: 0.8468
# Epoch 17/30
# 1/1 [==============================] - 5s 5s/step - loss: 0.3142 - accuracy: 0.8548
# Epoch 18/30
# 1/1 [==============================] - 5s 5s/step - loss: 0.2468 - accuracy: 0.8871
# Epoch 19/30
# 1/1 [==============================] - 8s 8s/step - loss: 0.1778 - accuracy: 0.9758
# Epoch 20/30
# 1/1 [==============================] - 5s 5s/step - loss: 0.1569 - accuracy: 0.9435
# Epoch 21/30
# 1/1 [==============================] - 6s 6s/step - loss: 0.1313 - accuracy: 0.9677
# Epoch 22/30
# 1/1 [==============================] - 6s 6s/step - loss: 0.0973 - accuracy: 0.9839
# Epoch 23/30
# 1/1 [==============================] - 5s 5s/step - loss: 0.0808 - accuracy: 0.9919
# Epoch 24/30
# 1/1 [==============================] - 7s 7s/step - loss: 0.0867 - accuracy: 0.9758
# Epoch 25/30
# 1/1 [==============================] - 5s 5s/step - loss: 0.0782 - accuracy: 0.9597
# Epoch 26/30
# 1/1 [==============================] - 5s 5s/step - loss: 0.0421 - accuracy: 1.0000
# Epoch 27/30
# 1/1 [==============================] - 7s 7s/step - loss: 0.0512 - accuracy: 0.9839
# Epoch 28/30
# 1/1 [==============================] - 5s 5s/step - loss: 0.0339 - accuracy: 1.0000
# Epoch 29/30
# 1/1 [==============================] - 6s 6s/step - loss: 0.0270 - accuracy: 1.0000
# Epoch 30/30
# 1/1 [==============================] - 6s 6s/step - loss: 0.0242 - accuracy: 1.0000
# 2/2 [==============================] - 1s 122ms/step - loss: 0.6234 - accuracy: 0.8750
# DO CHINH XAC 0.875
# HAM MAT MAT 0.623405933380127

# %%
model.save('/content/drive/MyDrive/Colab Notebooks/Data/Flower/875_30LAN.h5')

# %%
import numpy as np
import matplotlib.pyplot as plt
file_path = '/content/drive/MyDrive/Colab Notebooks/Data/Flower/sakura0.jpg'

test_img  = load_img(file_path, color_mode='rgb', target_size=(128, 128))
img_arr   = img_to_array(test_img).reshape(1, 128, 128, 3)/255
class_pred = np.argmax(model.predict(img_arr))
print("Predicted class:", class_names[class_pred])

plt.imshow(test_img)
# Out:
# 1/1 [==============================] - 0s 99ms/step
# Predicted class: sakura

# %%
file_path = '/content/drive/MyDrive/Colab Notebooks/Data/Flower/sakura1.jpg'

test_img  = load_img(file_path, color_mode='rgb', target_size=(128, 128))
img_arr   = img_to_array(test_img).reshape(1, 128, 128, 3)/255

class_pred = np.argmax(model.predict(img_arr))
print("Predicted class:", class_names[class_pred])
plt.imshow(test_img)
# Out:
# 1/1 [==============================] - 0s 62ms/step
# Predicted class: sakura

# %%
file_path = '/content/drive/MyDrive/Colab Notebooks/Data/Flower/rose1.jpg'

test_img  = load_img(file_path, color_mode='rgb', target_size=(128, 128))
img_arr   = img_to_array(test_img).reshape(1, 128, 128, 3)/255

class_pred = np.argmax(model.predict(img_arr))
print("Predicted class:", class_names[class_pred])
plt.imshow(test_img)
# Out:
# 1/1 [==============================] - 0s 35ms/step
# Predicted class: rose

# %%
file_path = '/content/drive/MyDrive/Colab Notebooks/Data/Flower/rose0.jpg'

test_img  = load_img(file_path, color_mode='rgb', target_size=(128, 128))
img_arr   = img_to_array(test_img).reshape(1, 128, 128, 3)/255

class_pred = np.argmax(model.predict(img_arr))
print("Predicted class:", class_names[class_pred])
plt.imshow(test_img)
# Out:
# 1/1 [==============================] - 0s 35ms/step
# Predicted class: rose

# %%
file_path = '/content/drive/MyDrive/Colab Notebooks/Data/Flower/daisy1.jpg'

test_img  = load_img(file_path, color_mode='rgb', target_size=(128, 128))
img_arr   = img_to_array(test_img).reshape(1, 128, 128, 3)/255

class_pred = np.argmax(model.predict(img_arr))
print("Predicted class:", class_names[class_pred])
plt.imshow(test_img)
# Out:
# 1/1 [==============================] - 0s 56ms/step
# Predicted class: daisy

# %%
file_path = '/content/drive/MyDrive/Colab Notebooks/Data/Flower/daisy0.jpg'

test_img  = load_img(file_path, color_mode='rgb', target_size=(128, 128))
img_arr   = img_to_array(test_img).reshape(1, 128, 128, 3)/255

class_pred = np.argmax(model.predict(img_arr))
print("Predicted class:", class_names[class_pred])
plt.imshow(test_img)
# Out:
# 1/1 [==============================] - 0s 45ms/step
# Predicted class: daisy

# %%
file_path = '/content/drive/MyDrive/Colab Notebooks/Data/Flower/lotus0.jpg'

test_img  = load_img(file_path, color_mode='rgb', target_size=(128, 128))
img_arr   = img_to_array(test_img).reshape(1, 128, 128, 3)/255

class_pred = np.argmax(model.predict(img_arr))
print("Predicted class:", class_names[class_pred])
plt.imshow(test_img)
# Out:
# 1/1 [==============================] - 0s 35ms/step
# Predicted class: lotus

# %%
file_path = '/content/drive/MyDrive/Colab Notebooks/Data/Flower/lotus.jpg'

test_img  = load_img(file_path, color_mode='rgb', target_size=(128, 128))
img_arr   = img_to_array(test_img).reshape(1, 128, 128, 3)/255

class_pred = np.argmax(model.predict(img_arr))
print("Predicted class:", class_names[class_pred])
plt.imshow(test_img)
# Out:
# 1/1 [==============================] - 0s 35ms/step
# Predicted class: lotus

# %%
#MTCNN multi task cascaded cnn
# facenet resnet VGG16 R_CNN YOLO FASTERRCNN

# %%
pip install mtcnn
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 54.7 MB/s eta 0:00:00
# ...

# %%
import matplotlib.pyplot as plt
from mtcnn import MTCNN
filename ='/content/drive/MyDrive/Colab Notebooks/aaaa.jpg'

img= plt.imread(filename)

detector = MTCNN()
faces = detector.detect_faces(img)
for face in faces:
  print(face)
  #box 4 gia tri
  #confidence  do chinh xac
  #keypoint
# Out:
# ...
# 20/20 [==============================] - 1s 24ms/step
# {'box': [1329, 375, 91, 114], 'confidence': 0.9999995827674866, 'keypoints': {'left_eye': (1349, 414), 'right_eye': (1388, 415), 'nose': (1362, 429), 'mouth_left': (1347, 456), 'mouth_right': (1384, 458)}}
# {'box': [1044, 379, 81, 109], 'confidence': 0.9999995827674866, 'keypoints': {'left_eye': (1069, 418), 'right_eye': (1104, 424), 'nose': (1083, 436), 'mouth_left': (1067, 458), 'mouth_right': (1093, 463)}}
# {'box': [863, 498, 97, 122], 'confidence': 0.9999992251396179, 'keypoints': {'left_eye': (896, 541), 'right_eye': (939, 546), 'nose': (920, 564), 'mouth_left': (896, 587), 'mouth_right': (934, 592)}}
# {'box': [561, 720, 140, 180], 'confidence': 0.9999950528144836, 'keypoints': {'left_eye': (588, 781), 'right_eye': (648, 779), 'nose': (610, 806), 'mouth_left': (593, 853), 'mouth_right': (640, 851)}}
# ...

# %%
plt.imshow(img)

# %%
#ve duong bao cho tung guong mat
import matplotlib.pyplot as plt
from mtcnn import MTCNN
filename ='/content/drive/MyDrive/Colab Notebooks/aaaa.jpg'
i=0
img= plt.imread(filename)
detector = MTCNN()
faces = detector.detect_faces(img)
plt.imshow(img)
ax=plt.gca()
for face in faces :
  i=i+1
  x,y,width,height=face['box']
  rect=plt.Rectangle((x,y),width,height, fill=False, color ='red')
  ax.add_patch(rect) #muon them gi vao hinh anh thi add vao
  plt.savefig('/content/drive/MyDrive/Colab Notebooks/Data/aasdas.jpg')
plt.show()
print(i)
#ve keypoint
for face in faces :
  x,y,width,height=face['box']
  rect=plt.Rectangle((x,y),width,height, fill=False, color ='red')
  ax.add_patch(rect)
  for key,value in face['keypoints'].items():
    dot=plt.Circle(value,radius= 2,color='red')
    ax.add_patch(dot)
plt.show()
# Out:
# ...
# 20/20 [==============================] - 1s 37ms/step
# 67

# %%
import matplotlib.pyplot as plt
from mtcnn import MTCNN
filename ='/content/drive/MyDrive/Colab Notebooks/aaaa.jpg'
i=0
img= plt.imread(filename)
detector = MTCNN()
faces = detector.detect_faces(img)
plt.imshow(img)
ax=plt.gca()

#ve keypoint
for face in faces :
  x,y,width,height=face['box']
  rect=plt.Rectangle((x,y),width,height, fill=False, color ='red')
  ax.add_patch(rect)
  for key,value in face['keypoints'].items():
    dot=plt.Circle(value,radius= 2,color='red')
    ax.add_patch(dot)
plt.show()
# Out:
# ...
# 20/20 [==============================] - 1s 23ms/step

# %%
import matplotlib.pyplot as plt
from mtcnn import MTCNN
filename ='/content/drive/MyDrive/Colab Notebooks/dk1.jpg'
img= plt.imread(filename)
detector = MTCNN()
faces = detector.detect_faces(img)

plt.imshow(img)
ax=plt.gca()

#ve keypoint
for face in faces :
  print(face) # tuy th, if do tu tin > ? thi hien thi
  x,y,width,height=face['box']
  rect=plt.Rectangle((x,y),width,height, fill=False, color ='red')
  ax.add_patch(rect)
  for key,value in face['keypoints'].items():
    dot=plt.Circle(value,radius= 2,color='red')
    ax.add_patch(dot)
plt.show()
print(face)
# Out:
# ...
# 1/1 [==============================] - 0s 122ms/step
# {'box': [174, 61, 62, 70], 'confidence': 0.9995827078819275, 'keypoints': {'left_eye': (188, 85), 'right_eye': (214, 83), 'nose': (197, 103), 'mouth_left': (188, 115), 'mouth_right': (212, 115)}}
# {'box': [451, 75, 59, 70], 'confidence': 0.9973211288452148, 'keypoints': {'left_eye': (471, 101), 'right_eye': (495, 101), 'nose': (483, 119), 'mouth_left': (472, 127), 'mouth_right': (492, 128)}}
# {'box': [49, 103, 51, 60], 'confidence': 0.9607297778129578, 'keypoints': {'left_eye': (64, 126), 'right_eye': (83, 126), 'nose': (72, 140), 'mouth_left': (65, 148), 'mouth_right': (82, 147)}}
# {'box': [49, 103, 51, 60], 'confidence': 0.9607297778129578, 'keypoints': {'left_eye': (64, 126), 'right_eye': (83, 126), 'nose': (72, 140), 'mouth_left': (65, 148), 'mouth_right': (82, 147)}}

# %%
import matplotlib.pyplot as plt
from mtcnn import MTCNN


def draw_faces(filename,result_list):
  data = plt.imread(filename)
  for i in range (len(result_list)):
    x1,y1,width,height = result_list[i]['box']
    x2,y2= x1+width, y1+height
    plt.subplot(1,len(result_list),i+1)
    plt.axis('off')  #bo duong vien do thi
    plt.imshow(data[y1:y2,x1:x2])

    name= 'anhcat'+str(i)+'.jpg'
    link= '/content/drive/MyDrive/Colab Notebooks/'+name
    plt.savefig(name)


  plt.show()
  
filename ='/content/drive/MyDrive/Colab Notebooks/aa.jpg'
img= plt.imread(filename)
detector = MTCNN()
faces = detector.detect_faces(img)
draw_faces(filename,faces)
# Out:
# ...
# 4/4 [==============================] - 0s 22ms/step

# %%
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions
import numpy as np

model = ResNet50(weights='imagenet')

img_path = '/content/drive/MyDrive/Colab Notebooks/MTCNN/cat.jpg'
img = image.load_img(img_path, target_size=(224, 224))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

preds = model.predict(x)

print('Predicted:', decode_predictions(preds, top=3)[0])



img_path = '/content/drive/MyDrive/Colab Notebooks/MTCNN/haili.jpg'
img = image.load_img(img_path, target_size=(224, 224))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

preds = model.predict(x)

print('Predicted:', decode_predictions(preds, top=3)[0])
#hai ly 9x%, chon nau 0,005%, rai ca 1%


# resnet tuong tu cifar, nhan dien dong vat.... ko nhan dien guong mat

#facenet nhan dien guong mat
# Out:
# 1/1 [==============================] - 1s 802ms/step
# Predicted: [('n02123394', 'Persian_cat', 0.49799463), ('n02123597', 'Siamese_cat', 0.3710086), ('n02085782', 'Japanese_spaniel', 0.030738415)]
# 1/1 [==============================] - 0s 138ms/step
# Predicted: [('n02363005', 'beaver', 0.9894253), ('n02444819', 'otter', 0.009611923), ('n02442845', 'mink', 0.0005454444)]
